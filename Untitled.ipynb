# %%
import yfinance as yf

# %%
dal = yf.Ticker("DAL")

# %%
# get stock info
dal.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'currency': 'USD',
#  'sharesOutstanding': 637825984,
#  'bookValue': 22.525,
#  'fiftyDayAverage': 24.536285,
#  'fiftyDayAverageChange': 7.5337143,
#  'fiftyDayAverageChangePercent': 0.3070438,
#  'twoHundredDayAverage': 42.02089,
#  'twoHundredDayAverageChange': -9.95089,
#  'twoHundredDayAverageChangePercent': -0.23680817,
#  'marketCap': 20455079936,
#  'forwardPE': 10.412338,
#  'priceToBook': 1.4237514,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'tradeable': False,
#  'exchange': 'NYQ',
#  'shortName': 'Delta Air Lines, Inc.',
#  'longName': 'Delta Air Lines, Inc.',
#  'messageBoardId': 'finmb_266311',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'REGULAR',
#  'firstTradeDateMilliseconds': 1178199000000,
#  'priceHint': 2,
#  'regularMarketChange': -2.0999985,
#  'regularMarketChangePercent': -6.1457376,
#  'regularMarketTime': 1591804591,
#  'regularMarketPrice': 32.07,
#  'regularMarketDayHigh': 32.53,
#  'regularMarketDayRange': '29.76 - 32.53',
#  'regularMarketDayLow': 29.76,
#  'regularMarketVolume': 50073165,
#  'regularMarketPreviousClose': 34.17,
#  'bid': 31.87,
#  'ask': 31.88,
#  'bidSize': 9,
#  'askSize': 11,
#  'fullExchangeName': 'NYSE',
#  'financialCurrency': 'USD',
#  'regularMarketOpen': 32.24,
#  'averageDailyVolume3Month': 58886526,
#  'averageDailyVolume10Day': 80319228,
#  'fiftyTwoWeekLowChange': 14.559999,
#  'fiftyTwoWeekLowChangePercent': 0.8315248,
#  'fiftyTwoWeekRange': '17.51 - 63.44',
#  'fiftyTwoWeekHighChange': -31.369999,
#  'fiftyTwoWeekHighChangePercent': -0.49448296,
#  'fiftyTwoWeekLow': 17.51,
#  'fiftyTwoWeekHigh': 63.44,
#  'dividendDate': 1583971200,
#  'earningsTimestamp': 1587553209,
#  'earningsTimestampStart': 1594312200,
#  'earningsTimestampEnd': 1594657800,
#  'trailingAnnualDividendRate': 1.558,
#  'trailingPE': 5.9060774,
#  'trailingAnnualDividendYield': 0.045595553,
#  'epsTrailingTwelveMonths': 5.43,
#  'epsForward': 3.08,
#  'displayName': 'Delta Air Lines',
#  'symbol': 'DAL'}

# %%
# get historical market data
hist = dal.history(period="max")

# %%
# show actions (dividends, splits)
dal.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2013-08-07     0.0600           0.0
# 2013-11-04     0.0600           0.0
# 2014-02-19     0.0600           0.0
# 2014-05-07     0.0600           0.0
# 2014-08-06     0.0900           0.0
# 2014-11-05     0.0900           0.0
# 2015-02-18     0.0900           0.0
# 2015-05-06     0.0900           0.0
# 2015-08-05     0.1350           0.0
# 2015-11-04     0.1350           0.0
# 2016-02-12     0.1350           0.0
# 2016-05-09     0.1350           0.0
# 2016-08-10     0.2025           0.0
# 2016-11-08     0.2025           0.0
# 2017-02-22     0.2025           0.0
# 2017-05-17     0.2025           0.0
# 2017-08-21     0.3050           0.0
# 2017-11-16     0.3050           0.0
# 2018-02-22     0.3050           0.0
# 2018-05-10     0.3050           0.0
# 2018-07-25     0.3500           0.0
# 2018-11-06     0.3500           0.0
# 2019-02-28     0.3500           0.0
# 2019-05-01     0.3500           0.0
# 2019-07-24     0.4025           0.0
# 2019-10-23     0.4030           0.0
# 2020-02-19     0.4025           0.0

# %%
# show dividends
dal.dividends
# Out:
# Date
# 2013-08-07    0.0600
# 2013-11-04    0.0600
# 2014-02-19    0.0600
# 2014-05-07    0.0600
# 2014-08-06    0.0900
# 2014-11-05    0.0900
# 2015-02-18    0.0900
# 2015-05-06    0.0900
# 2015-08-05    0.1350
# 2015-11-04    0.1350
# 2016-02-12    0.1350
# 2016-05-09    0.1350
# 2016-08-10    0.2025
# 2016-11-08    0.2025
# 2017-02-22    0.2025
# 2017-05-17    0.2025
# 2017-08-21    0.3050
# 2017-11-16    0.3050
# 2018-02-22    0.3050
# 2018-05-10    0.3050
# 2018-07-25    0.3500
# 2018-11-06    0.3500
# 2019-02-28    0.3500
# 2019-05-01    0.3500
# 2019-07-24    0.4025
# 2019-10-23    0.4030
# 2020-02-19    0.4025
# Name: Dividends, dtype: float64

# %%
# show splits
dal.splits
# Out:
# Series([], Name: Stock Splits, dtype: int64)

# %%
# show financials
dal.financials
dal.quarterly_financials

# show major holders
stock.major_holders

# show institutional holders
stock.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
